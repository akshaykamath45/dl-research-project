# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# Set random seed for reproducibility
tf.random.set_seed(42)

# Constants
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 50
NUM_CLASSES = 400

def create_data_generators():
    # Training data generator with augmentation
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest'
    )
    
    # Test data generator (only rescaling)
    test_datagen = ImageDataGenerator(rescale=1./255)
    val_datagen = ImageDataGenerator(rescale=1./255)
    
    # Replace 'path_to_data' with your actual data path
    train_generator = train_datagen.flow_from_directory(
        '/kaggle/input/400birds/400BirdSpecies/train',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training'
    )
    
    validation_generator = val_datagen.flow_from_directory(
        '/kaggle/input/400birds/400BirdSpecies/valid',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical'
    )
    
    test_generator = test_datagen.flow_from_directory(
        '/kaggle/input/400birds/400BirdSpecies/test',
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        shuffle=False
    )
    
    return train_generator, validation_generator, test_generator

def create_model():
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    
    # Freeze the base model
    base_model.trainable = False
    
    model = tf.keras.Sequential([
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(1024, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

def create_callbacks():
    checkpoint = ModelCheckpoint(
        'best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        mode='max',
        verbose=1
    )
    
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=3,
        min_lr=1e-6,
        verbose=1
    )
    
    return [checkpoint, early_stopping, reduce_lr]

# %%
# Add these imports to the previous ones
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.models import Model

def calculate_class_weights(train_generator):
    """Calculate class weights to handle class imbalance"""
    # Get all labels from the generator
    labels = []
    steps = len(train_generator)
    for i in range(steps):
        _, y = train_generator[i]
        labels.extend(np.argmax(y, axis=1))
        
    # Calculate class weights
    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(labels),
        y=labels
    )
    
    return dict(enumerate(class_weights))

def create_model_with_unfreezing():
    """Create model with gradual unfreezing capability"""
    base_model = Xception(
        weights='imagenet',
        include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
    )
    
    # Initially freeze the base model
    base_model.trainable = False
    
    # Create the model
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base_model(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)
    
    model = Model(inputs, outputs)
    
    return model, base_model

def train_model():
    # Create data generators
    train_generator, validation_generator, test_generator = create_data_generators()
    
    # Calculate class weights
    class_weights = calculate_class_weights(train_generator)
    
    # Create model
    model, base_model = create_model_with_unfreezing()
    
    # Training history storage
    all_history = []
    
    # Phase 1: Train only the top layers
    print("Phase 1: Training top layers...")
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    history1 = model.fit(
        train_generator,
        epochs=10,
        validation_data=validation_generator,
        callbacks=create_callbacks(),
        class_weight=class_weights
    )
    all_history.append(history1)
    
    # Phase 2: Unfreeze and train the last few Xception blocks
    print("Phase 2: Fine-tuning last Xception blocks...")
    for layer in base_model.layers[-30:]:
        layer.trainable = True
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    history2 = model.fit(
        train_generator,
        epochs=20,
        validation_data=validation_generator,
        callbacks=create_callbacks(),
        class_weight=class_weights
    )
    all_history.append(history2)
    
    # Phase 3: Unfreeze all layers
    print("Phase 3: Fine-tuning all layers...")
    base_model.trainable = True
    
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-5),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    history3 = model.fit(
        train_generator,
        epochs=20,
        validation_data=validation_generator,
        callbacks=create_callbacks(),
        class_weight=class_weights
    )
    all_history.append(history3)
    
    return model, all_history, test_generator

def plot_training_history(all_history):
    """Plot training metrics"""
    # Combine histories
    acc = []
    val_acc = []
    loss = []
    val_loss = []
    
    for history in all_history:
        acc.extend(history.history['accuracy'])
        val_acc.extend(history.history['val_accuracy'])
        loss.extend(history.history['loss'])
        val_loss.extend(history.history['val_loss'])
    
    epochs = range(1, len(acc) + 1)
    
    # Accuracy plot
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training accuracy')
    plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

def evaluate_model(model, test_generator):
    """Evaluate model and display metrics"""
    # Get predictions
    predictions = model.predict(test_generator)
    y_pred = np.argmax(predictions, axis=1)
    y_true = test_generator.classes
    
    # Calculate metrics
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))
    
    # Plot confusion matrix (for top N classes due to large number of classes)
    plt.figure(figsize=(15, 15))
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(cm[:20, :20], annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix (Top 20 Classes)')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def analyze_errors(model, test_generator, num_samples=5):
    """Show examples of correct and incorrect predictions"""
    predictions = model.predict(test_generator)
    pred_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    
    # Get class labels
    class_labels = {v: k for k, v in test_generator.class_indices.items()}
    
    # Find correct and incorrect predictions
    correct_indices = np.where(pred_classes == true_classes)[0]
    incorrect_indices = np.where(pred_classes != true_classes)[0]
    
    # Plot some correct predictions
    plt.figure(figsize=(15, 5))
    plt.suptitle('Correct Predictions', y=1.05)
    for i in range(num_samples):
        if i < len(correct_indices):
            idx = correct_indices[i]
            img = test_generator[idx // BATCH_SIZE][0][idx % BATCH_SIZE]
            plt.subplot(1, num_samples, i+1)
            plt.imshow(img)
            plt.title(f'True: {class_labels[true_classes[idx]]}')
            plt.axis('off')
    plt.show()
    
    # Plot some incorrect predictions
    plt.figure(figsize=(15, 5))
    plt.suptitle('Incorrect Predictions', y=1.05)
    for i in range(num_samples):
        if i < len(incorrect_indices):
            idx = incorrect_indices[i]
            img = test_generator[idx // BATCH_SIZE][0][idx % BATCH_SIZE]
            plt.subplot(1, num_samples, i+1)
            plt.imshow(img)
            plt.title(f'True: {class_labels[true_classes[idx]]}\nPred: {class_labels[pred_classes[idx]]}')
            plt.axis('off')
    plt.show()

# %%
# Train the model
model, history, test_generator = train_model()

# Plot training history
plot_training_history(history)

# Evaluate model
evaluate_model(model, test_generator)

# Analyze errors
analyze_errors(model, test_generator)
# Out:
# Found 58388 images belonging to 400 classes.
# Found 2000 images belonging to 400 classes.
# Found 2000 images belonging to 400 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Phase 1: Training top layers...
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733906852.659185     111 service.cc:145] XLA service 0x7969180031d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1733906852.659241     111 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#    2/1825 ━━━━━━━━━━━━━━━━━━━━ 2:19 77ms/step - accuracy: 0.0000e+00 - loss: 6.4710
# I0000 00:00:1733906861.240096     111 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.2252 - loss: 3.9043
# Epoch 1: val_accuracy improved from -inf to 0.72000, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 700s 375ms/step - accuracy: 0.2253 - loss: 3.9038 - val_accuracy: 0.7200 - val_loss: 1.0213 - learning_rate: 0.0010
# Epoch 2/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.4722 - loss: 2.1437
# Epoch 2: val_accuracy improved from 0.72000 to 0.75600, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 661s 361ms/step - accuracy: 0.4722 - loss: 2.1437 - val_accuracy: 0.7560 - val_loss: 0.8521 - learning_rate: 0.0010
# Epoch 3/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.5187 - loss: 1.9227
# Epoch 3: val_accuracy improved from 0.75600 to 0.79350, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 655s 357ms/step - accuracy: 0.5187 - loss: 1.9227 - val_accuracy: 0.7935 - val_loss: 0.7126 - learning_rate: 0.0010
# Epoch 4/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.5479 - loss: 1.8109
# Epoch 4: val_accuracy improved from 0.79350 to 0.81700, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 655s 357ms/step - accuracy: 0.5479 - loss: 1.8109 - val_accuracy: 0.8170 - val_loss: 0.6610 - learning_rate: 0.0010
# Epoch 5/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.5730 - loss: 1.6965
# Epoch 5: val_accuracy improved from 0.81700 to 0.83850, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 652s 356ms/step - accuracy: 0.5730 - loss: 1.6965 - val_accuracy: 0.8385 - val_loss: 0.6005 - learning_rate: 0.0010
# Epoch 6/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5933 - loss: 1.6059
# Epoch 6: val_accuracy did not improve from 0.83850
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 650s 355ms/step - accuracy: 0.5933 - loss: 1.6059 - val_accuracy: 0.8325 - val_loss: 0.5635 - learning_rate: 0.0010
# Epoch 7/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.6154 - loss: 1.5110
# Epoch 7: val_accuracy did not improve from 0.83850
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 648s 354ms/step - accuracy: 0.6154 - loss: 1.5110 - val_accuracy: 0.8250 - val_loss: 0.5579 - learning_rate: 0.0010
# Epoch 8/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.6253 - loss: 1.4596
# Epoch 8: val_accuracy improved from 0.83850 to 0.84900, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 653s 356ms/step - accuracy: 0.6253 - loss: 1.4596 - val_accuracy: 0.8490 - val_loss: 0.4861 - learning_rate: 0.0010
# Epoch 9/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.6381 - loss: 1.3904
# Epoch 9: val_accuracy did not improve from 0.84900
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 638s 348ms/step - accuracy: 0.6381 - loss: 1.3904 - val_accuracy: 0.8400 - val_loss: 0.5069 - learning_rate: 0.0010
# Epoch 10/10
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6492 - loss: 1.3489
# Epoch 10: val_accuracy did not improve from 0.84900
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 656s 358ms/step - accuracy: 0.6492 - loss: 1.3489 - val_accuracy: 0.8485 - val_loss: 0.4802 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# Phase 2: Fine-tuning last Xception blocks...
# Epoch 1/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.6495 - loss: 1.3970
# Epoch 1: val_accuracy improved from -inf to 0.90900, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 690s 368ms/step - accuracy: 0.6495 - loss: 1.3969 - val_accuracy: 0.9090 - val_loss: 0.3011 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7620 - loss: 0.8724
# Epoch 2: val_accuracy improved from 0.90900 to 0.92850, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 662s 361ms/step - accuracy: 0.7620 - loss: 0.8723 - val_accuracy: 0.9285 - val_loss: 0.2352 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8016 - loss: 0.7154
# Epoch 3: val_accuracy improved from 0.92850 to 0.94300, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 643s 351ms/step - accuracy: 0.8016 - loss: 0.7154 - val_accuracy: 0.9430 - val_loss: 0.1909 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8326 - loss: 0.6080
# Epoch 4: val_accuracy improved from 0.94300 to 0.94600, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 644s 351ms/step - accuracy: 0.8326 - loss: 0.6080 - val_accuracy: 0.9460 - val_loss: 0.1810 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8504 - loss: 0.5374
# Epoch 5: val_accuracy improved from 0.94600 to 0.95000, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 628s 343ms/step - accuracy: 0.8504 - loss: 0.5374 - val_accuracy: 0.9500 - val_loss: 0.1708 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8624 - loss: 0.4827
# Epoch 6: val_accuracy improved from 0.95000 to 0.96150, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 632s 345ms/step - accuracy: 0.8624 - loss: 0.4827 - val_accuracy: 0.9615 - val_loss: 0.1406 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.8770 - loss: 0.4419
# Epoch 7: val_accuracy did not improve from 0.96150
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 625s 341ms/step - accuracy: 0.8770 - loss: 0.4419 - val_accuracy: 0.9610 - val_loss: 0.1292 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.8883 - loss: 0.3854
# Epoch 8: val_accuracy did not improve from 0.96150
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 630s 344ms/step - accuracy: 0.8883 - loss: 0.3854 - val_accuracy: 0.9595 - val_loss: 0.1443 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8946 - loss: 0.3631
# Epoch 9: val_accuracy did not improve from 0.96150
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 628s 343ms/step - accuracy: 0.8946 - loss: 0.3631 - val_accuracy: 0.9565 - val_loss: 0.1335 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9026 - loss: 0.3343
# Epoch 10: val_accuracy did not improve from 0.96150
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 628s 343ms/step - accuracy: 0.9026 - loss: 0.3343 - val_accuracy: 0.9590 - val_loss: 0.1340 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9198 - loss: 0.2746
# Epoch 11: val_accuracy improved from 0.96150 to 0.96650, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 628s 343ms/step - accuracy: 0.9198 - loss: 0.2746 - val_accuracy: 0.9665 - val_loss: 0.1121 - learning_rate: 2.0000e-05
# Epoch 12/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9299 - loss: 0.2315
# Epoch 12: val_accuracy improved from 0.96650 to 0.96900, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 624s 340ms/step - accuracy: 0.9299 - loss: 0.2315 - val_accuracy: 0.9690 - val_loss: 0.1060 - learning_rate: 2.0000e-05
# Epoch 13/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9344 - loss: 0.2210
# Epoch 13: val_accuracy improved from 0.96900 to 0.96950, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 639s 349ms/step - accuracy: 0.9344 - loss: 0.2210 - val_accuracy: 0.9695 - val_loss: 0.1036 - learning_rate: 2.0000e-05
# Epoch 14/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9395 - loss: 0.2029
# Epoch 14: val_accuracy improved from 0.96950 to 0.97050, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 632s 345ms/step - accuracy: 0.9395 - loss: 0.2029 - val_accuracy: 0.9705 - val_loss: 0.1022 - learning_rate: 2.0000e-05
# Epoch 15/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9429 - loss: 0.1930
# Epoch 15: val_accuracy improved from 0.97050 to 0.97200, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 634s 346ms/step - accuracy: 0.9429 - loss: 0.1930 - val_accuracy: 0.9720 - val_loss: 0.0993 - learning_rate: 2.0000e-05
# Epoch 16/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9445 - loss: 0.1820
# Epoch 16: val_accuracy did not improve from 0.97200
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 637s 348ms/step - accuracy: 0.9445 - loss: 0.1820 - val_accuracy: 0.9700 - val_loss: 0.0961 - learning_rate: 2.0000e-05
# Epoch 17/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9443 - loss: 0.1795
# Epoch 17: val_accuracy did not improve from 0.97200
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 627s 342ms/step - accuracy: 0.9443 - loss: 0.1795 - val_accuracy: 0.9705 - val_loss: 0.0935 - learning_rate: 2.0000e-05
# Epoch 18/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9474 - loss: 0.1662
# Epoch 18: val_accuracy did not improve from 0.97200
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 622s 339ms/step - accuracy: 0.9474 - loss: 0.1662 - val_accuracy: 0.9700 - val_loss: 0.0948 - learning_rate: 2.0000e-05
# Epoch 19/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9481 - loss: 0.1612
# Epoch 19: val_accuracy did not improve from 0.97200
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 630s 344ms/step - accuracy: 0.9481 - loss: 0.1612 - val_accuracy: 0.9720 - val_loss: 0.0939 - learning_rate: 2.0000e-05
# Epoch 20/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.
20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9648 - loss: 0.1126
# Epoch 13: val_accuracy did not improve from 0.97700
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 635s 346ms/step - accuracy: 0.9648 - loss: 0.1126 - val_accuracy: 0.9765 - val_loss: 0.0803 - learning_rate: 2.0000e-06
# Epoch 14/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9655 - loss: 0.1101
# Epoch 14: val_accuracy improved from 0.97700 to 0.97800, saving model to best_model.keras
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 642s 350ms/step - accuracy: 0.9655 - loss: 0.1101 - val_accuracy: 0.9780 - val_loss: 0.0780 - learning_rate: 2.0000e-06
# Epoch 15/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9669 - loss: 0.1089
# Epoch 15: val_accuracy did not improve from 0.97800
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 642s 350ms/step - accuracy: 0.9669 - loss: 0.1089 - val_accuracy: 0.9765 - val_loss: 0.0777 - learning_rate: 2.0000e-06
# Epoch 16/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9657 - loss: 0.1071
# Epoch 16: val_accuracy did not improve from 0.97800
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 638s 348ms/step - accuracy: 0.9657 - loss: 0.1071 - val_accuracy: 0.9770 - val_loss: 0.0761 - learning_rate: 2.0000e-06
# Epoch 17/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.9678 - loss: 0.1041
# Epoch 17: val_accuracy did not improve from 0.97800
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 634s 346ms/step - accuracy: 0.9678 - loss: 0.1041 - val_accuracy: 0.9770 - val_loss: 0.0763 - learning_rate: 2.0000e-06
# Epoch 18/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.9670 - loss: 0.1034
# Epoch 18: val_accuracy did not improve from 0.97800
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 638s 348ms/step - accuracy: 0.9670 - loss: 0.1034 - val_accuracy: 0.9780 - val_loss: 0.0762 - learning_rate: 2.0000e-06
# Epoch 19/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9678 - loss: 0.1017
# Epoch 19: val_accuracy did not improve from 0.97800
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1e-06.
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 637s 348ms/step - accuracy: 0.9678 - loss: 0.1017 - val_accuracy: 0.9775 - val_loss: 0.0769 - learning_rate: 2.0000e-06
# Epoch 20/20
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9681 - loss: 0.0984
# Epoch 20: val_accuracy did not improve from 0.97800
# 1825/1825 ━━━━━━━━━━━━━━━━━━━━ 644s 352ms/step - accuracy: 0.9681 - loss: 0.0984 - val_accuracy: 0.9775 - val_loss: 0.0772 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 16.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 328ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       1.00      0.80      0.89         5
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         5
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         5
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         5
#            8       1.00      1.00      1.00         5
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         5
#           11       1.00      0.60      0.75         5
#           12       1.00      1.00      1.00         5
#           13       1.00      1.00      1.00         5
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         5
#           16       1.00      1.00      1.00         5
#           17       1.00      1.00      1.00         5
#           18       1.00      1.00      1.00         5
#           19       1.00      1.00      1.00         5
#           20       1.00      1.00      1.00         5
#           21       1.00      1.00      1.00         5
#           22       1.00      1.00      1.00         5
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         5
#           25       1.00      1.00      1.00         5
#           26       1.00      0.80      0.89         5
#           27       1.00      1.00      1.00         5
#           28       1.00      1.00      1.00         5
#           29       1.00      1.00      1.00         5
#           30       1.00      1.00      1.00         5
#           31       1.00      0.80      0.89         5
#           32       1.00      1.00      1.00         5
#           33       0.60      0.60      0.60         5
#           34       1.00      1.00      1.00         5
#           35       1.00      1.00      1.00         5
#           36       1.00      1.00      1.00         5
#           37       1.00      1.00      1.00         5
#           38       1.00      1.00      1.00